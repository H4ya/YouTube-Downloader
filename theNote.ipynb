# %%
from pytube import YouTube
from tkinter import *
from tkinter import filedialog

# %%
window=Tk()

# %%
window.title("Youtube Downloader")
window.geometry("600x320")
# Out:
# ''

# %%
label=Label(window,text="Enter the link of the video")
label.place(x=140,y=150)

# %%
window.mainloop()
